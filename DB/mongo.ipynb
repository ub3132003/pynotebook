# %%
import pymongo
mg=pymongo.MongoClient("mongodb://192.168.1.201:27017/") #连接 最后要有/

# %% [markdown]
# # a

# %%
db =mg["testlib"] # 选数据库 
test=db["default"] # 选表
#test=db.sites #选表
query=""
projection=""

feature={"image":1}

db2=mg["124"]
print(db2)
# Out:
# Database(MongoClient(host=['192.168.1.201:27017'], document_class=dict, tz_aware=False, connect=True), '124')

# %% [markdown]
# ## 插入数据

# %%
mydict = {"_id":"24422s", "name": "RUNOOB", "alexa": "10000", "url": "https://www.runoob.com" }
t2=db["t2"]

x=t2.insert_one(mydict)
print(x)
# x = test.insert_one(mydict) 
# print(x)
# id 在表等级就不能重复，不同表之间可以重复
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# <ipython-input-15-d1ca4ac7cf80> in <module>()
#       2 t2=db["t2"]
#       3
# ----> 4 x=t2.insert_one(mydict)
#       5 print(x)
#       6 # x = test.insert_one(mydict)
#
# c:\program files\python36\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     691                          write_concern=write_concern,
#     692                          bypass_doc_val=bypass_document_validation,
# --> 693                          session=session),
#     694             write_concern.acknowledged)
#     695
#
# c:\program files\python36\lib\site-packages\pymongo\collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     605             return self._insert_one(
#     606                 docs, ordered, check_keys, manipulate, write_concern, op_id,
# --> 607                 bypass_doc_val, session)
#     608
#     609         ids = []
#
# c:\program files\python36\lib\site-packages\pymongo\collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     593
#     594         self.__database.client._retryable_write(
# --> 595             acknowledged, _insert_command, session)
#     596
#     597         if not isinstance(doc, RawBSONDocument):
#
# c:\program files\python36\lib\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1246         """Internal retryable write helper."""
#    1247         with self._tmp_session(session) as s:
# -> 1248             return self._retry_with_session(retryable, func, s, None)
#    1249
#    1250     def __reset_server(self, address):
#
# c:\program files\python36\lib\site-packages\pymongo\mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1199                             raise last_error
#    1200                         retryable = False
# -> 1201                     return func(session, sock_info, retryable)
#    1202             except ServerSelectionTimeoutError:
#    1203                 if is_retrying():
#
# c:\program files\python36\lib\site-packages\pymongo\collection.py in _insert_command(session, sock_info, retryable_write)
#     590                 retryable_write=retryable_write)
#     591
# --> 592             _check_write_command_response(result)
#     593
#     594         self.__database.client._retryable_write(
#
# c:\program files\python36\lib\site-packages\pymongo\helpers.py in _check_write_command_response(result)
#     215     write_errors = result.get("writeErrors")
#     216     if write_errors:
# --> 217         _raise_last_write_error(write_errors)
#     218
#     219     error = result.get("writeConcernError")
#
# c:\program files\python36\lib\site-packages\pymongo\helpers.py in _raise_last_write_error(write_errors)
#     196     error = write_errors[-1]
#     197     if error.get("code") == 11000:
# --> 198         raise DuplicateKeyError(error.get("errmsg"), 11000, error)
#     199     raise WriteError(error.get("errmsg"), error.get("code"), error)
#     200
#
# DuplicateKeyError: E11000 duplicate key error collection: testlib.t2 index: _id_ dup key: { : "24422s" }

# %% [markdown]
# ### 引用其他表

# %%
mydict = {"_id":"2444422s", "data":}
 

x=test.insert_one(mydict)
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# <ipython-input-17-f94e22c6c88c> in <module>()
# ----> 1 mydict = {"_id":"2444422s", "data":t2.insert_one(mydict)}
#       2
#       3
#       4 x=test.insert_one(mydict)
#
# c:\program files\python36\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     691                          write_concern=write_concern,
#     692                          bypass_doc_val=bypass_document_validation,
# --> 693                          session=session),
#     694             write_concern.acknowledged)
#     695
#
# c:\program files\python36\lib\site-packages\pymongo\collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     605             return self._insert_one(
#     606                 docs, ordered, check_keys, manipulate, write_concern, op_id,
# --> 607                 bypass_doc_val, session)
#     608
#     609         ids = []
#
# c:\program files\python36\lib\site-packages\pymongo\collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     593
#     594         self.__database.client._retryable_write(
# --> 595             acknowledged, _insert_command, session)
#     596
#     597         if not isinstance(doc, RawBSONDocument):
#
# c:\program files\python36\lib\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1246         """Internal retryable write helper."""
#    1247         with self._tmp_session(session) as s:
# -> 1248             return self._retry_with_session(retryable, func, s, None)
#    1249
#    1250     def __reset_server(self, address):
#
# c:\program files\python36\lib\site-packages\pymongo\mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1199                             raise last_error
#    1200                         retryable = False
# -> 1201                     return func(session, sock_info, retryable)
#    1202             except ServerSelectionTimeoutError:
#    1203                 if is_retrying():
#
# c:\program files\python36\lib\site-packages\pymongo\collection.py in _insert_command(session, sock_info, retryable_write)
#     590                 retryable_write=retryable_write)
#     591
# --> 592             _check_write_command_response(result)
#     593
#     594         self.__database.client._retryable_write(
#
# c:\program files\python36\lib\site-packages\pymongo\helpers.py in _check_write_command_response(result)
#     215     write_errors = result.get("writeErrors")
#     216     if write_errors:
# --> 217         _raise_last_write_error(write_errors)
#     218
#     219     error = result.get("writeConcernError")
#
# c:\program files\python36\lib\site-packages\pymongo\helpers.py in _raise_last_write_error(write_errors)
#     196     error = write_errors[-1]
#     197     if error.get("code") == 11000:
# --> 198         raise DuplicateKeyError(error.get("errmsg"), 11000, error)
#     199     raise WriteError(error.get("errmsg"), error.get("code"), error)
#     200
#
# DuplicateKeyError: E11000 duplicate key error collection: testlib.t2 index: _id_ dup key: { : "24422s" }

# %% [markdown]
# ## 查询表中所有数据
# #只能查询一次结果 之后再使用打印dataAll 就变成空了

# %%
dataAll=db.default.find()
dataInclusion=db.default.find(projection ={"imageId":1,"rect":1}) # 只返回指定键
dataExclusion=db.default.find( projection ={"name": 0}) # 只返回指定键之外的其他所有键

# %% [markdown]
# ## 生成数据

# %%
all=[i for i in dataAll]
inclusion=[ i for i in dataInclusion]
exclusion=[i for i in dataExclusion]
inclusion
# Out:
# [{'_id': ObjectId('5bf624b3d024014c98c63f2e')},
#  {'_id': ObjectId('5bf75ff2d02401316c3f2a17'),
#   'rect': [85, 53, 244, 253],
#   'imageId': ''}]

# %% [markdown]
# ## 序列化数据

# %%
from bson import json_util as jsonb
print( jsonb.dumps( dataAll))
dataAll
# Out:
# [{"_id": {"$oid": "5bf4dd82d02401440c291abb"}, "name": "RUNOOB", "alexa": "10000", "url": "https://www.runoob.com"}, {"_id": {"$oid": "5bf4dd8dd0240141dccd2857"}, "name": "RUNOOB", "alexa": "10000", "url": "https://www.runoob.com"}, {"_id": {"$oid": "5bf50755d024012878394123"}, "image": {"$binary": "...", "$type": "00"}, "alignedImage": 2, "feature": 3, "rect": 4, "imageId": 5, "info": null}, {"_id": {"$oid": "5bf50790d0240150c413ad5b"}, "image": {"$binary": "...", "$type": "00"}, "alignedImage": 2, "feature": 3, "rect": 4, "imageId": 5, "info": null}, {"_id": {"$oid": "5bf50c17d024014010f49635"}, "image": {"$binary": "...", "$type": "00"}, "alignedImage": {"$binary": "Mg==", "$type": "00"}, "feature": {"$binary": "Mw==", "$type": "00"}, "rect": 4, "imageId": 5, "info": null}]

# %% [markdown]
# ## 统计

# %%
# 列出数据库
print(mg.database_names())
# 列出集合
print(db.collection_names())
# Out:
# ['admin', 'config', 'face', 'local']
# ['testlib']
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: database_names is deprecated. Use list_database_names instead.
#
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: collection_names is deprecated. Use list_collection_names instead.
#   after removing the cwd from sys.path.

# %%
# 死了 与Python kernel 冲突?
dbb=mg["face"]
dbb["testlib"].count()
# Out:
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   This is separate from the ipykernel package so we can avoid doing imports until
# 3

# %%
a=[ [1,3,4],[2],[3]]
a[:][:2]
# Out:
# [[1, 3, 4], [2]]

# %%
# Out:
# {'23': 33}

# %%
import pathlib

pathlib.Path("./111.txt").is_file()
# Out:
# False
