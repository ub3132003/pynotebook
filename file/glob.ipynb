# %%
# 搜索
import glob
glob.glob(r"X:\share\image\Aberdeen\*.jpg")
# Out:
# ['X:\\share\\image\\Aberdeen\\adrian1.jpg',
#  'X:\\share\\image\\Aberdeen\\adrian2.jpg',
#  'X:\\share\\image\\Aberdeen\\adrian3.jpg',
#  'X:\\share\\image\\Aberdeen\\adrian4.jpg',
#  'X:\\share\\image\\Aberdeen\\alec1.jpg',
#  'X:\\share\\image\\Aberdeen\\alison1.jpg',
#  'X:\\share\\image\\Aberdeen\\alison2.jpg',
#  'X:\\share\\image\\Aberdeen\\alison3.jpg',
#  'X:\\share\\image\\Aberdeen\\alison4.jpg',
#  'X:\\share\\image\\Aberdeen\\alister1.jpg',
#  'X:\\share\\image\\Aberdeen\\alister2.jpg',
#  'X:\\share\\image\\Aberdeen\\alister3.jpg',
#  'X:\\share\\image\\Aberdeen\\alister4.jpg',
#  'X:\\share\\image\\Aberdeen\\amellanby1.jpg',
#  'X:\\share\\image\\Aberdeen\\amellanby10.jpg',
#  'X:\\share\\image\\Aberdeen\\amellanby11.jpg',
#  'X:\\share\\image\\Aberdeen\\amellanby12.jpg',
#  'X:\\share\\image\\Aberdeen\\amellanby13.jpg',
#  'X:\\share\\image\\Aberdeen\\amellanby14.jpg',
#  'X:\\share\\image\\Aberdeen\\amellanby15.jpg',
#  'X:\\share\\image\\Aberdeen\\amellanby16.jpg',
# ...
