# %%
import os
os.chdir(r"D:/myGit/github/facenet/src")
print(os.getcwd())
# Out:
# D:\myGit\github\facenet\src

# %%
# %run ./align/align_dataset_mtcnn.py X:\share\image\lfw   X:\share\image\aligen160_lfw  --image_size 160
# Out:
# Creating networks and loading parameters
# X:\share\image\lfw\AJ_Cook\AJ_Cook_0001.jpg
# D:\myGit\github\facenet\src\align\align_dataset_mtcnn.py:83: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = misc.imread(image_path)
# D:\myGit\github\facenet\src\align\align_dataset_mtcnn.py:124: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   scaled = misc.imresize(cropped, (args.image_size, args.image_size), interp='bilinear')
# D:\myGit\github\facenet\src\align\align_dataset_mtcnn.py:131: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   misc.imsave(output_filename_n, scaled)
# X:\share\image\lfw\AJ_Lamas\AJ_Lamas_0001.jpg
# ...

# %% [markdown]
# * 可能时训练时的问题，查看face点输出。
# * 可能时归一化数据有问题
# * 大部分人会预测为同一个人，可能时权重问题

# %%
# 首先排除数据问题，使用lfw数据集
# 训练分类
# %run classifier.py TRAIN  X:\share\image\aligen160_lfw  X:/share/model/20180402-114759/20180402-114759.pb X:\share\model\classifiter\lfw.pkl --batch_size 1000 --min_nrof_images_per_class 40 --nrof_train_images_per_class 35 --use_split_dataset
# Out:
# D:\myGit\github\facenet\src\classifier.py:60: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(len(cls.image_paths)>0, 'There must be at least one image for each class in the dataset')
# Number of classes: 19
# Number of images: 665
# Loading feature extraction model
# Model filename: X:/share/model/20180402-114759/20180402-114759.pb
# Calculating features for images
# Training classifier
# Saved classifier model to file "X:\share\model\classifiter\lfw.pkl"

# %%
            # 测试分类效果
# %run classifier.py CLASSIFY X:\share\image\aligen160_lfw   X:/share/model/20180402-114759/20180402-114759.pb  X:\share\model\classifiter\lfw.pkl --batch_size 1000 --min_nrof_images_per_class 40 --nrof_train_images_per_class 35 --use_split_dataset
# Out:
# D:\myGit\github\facenet\src\classifier.py:60: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(len(cls.image_paths)>0, 'There must be at least one image for each class in the dataset')
# Number of classes: 19
# Number of images: 1202
# Loading feature extraction model
# Model filename: X:/share/model/20180402-114759/20180402-114759.pb
# Calculating features for images
# Testing classifier
# Loaded classifier model from file "X:\share\model\classifiter\lfw.pkl"
#    0  Ariel Sharon: 0.651
#    1  Ariel Sharon: 0.813
#    2  Ariel Sharon: 0.793
#    3  Ariel Sharon: 0.798
#    4  Ariel Sharon: 0.735
#    5  Ariel Sharon: 0.762
#    6  Ariel Sharon: 0.732
#    7  Ariel Sharon: 0.811
#    8  Ariel Sharon: 0.712
#    9  Ariel Sharon: 0.674
#   10  Ariel Sharon: 0.796
#   11  Ariel Sharon: 0.662
#   12  Ariel Sharon: 0.805
#   13  Ariel Sharon: 0.808
#   14  Ariel Sharon: 0.760
#   15  Ariel Sharon: 0.662
#   16  Ariel Sharon: 0.709
# ...

# %% [markdown]
# * 明显的是数据集或者输入参数有问题
# * 为什么例子中 的分类数和图片数量不成比例， 每个分类大约有30张图片，而我的数据身上每个分类平均4张图片。
#
# 查看了分类结果上的数据，每个人在训练时确实有20-30张照片，所以是没有足够数据SVM是无法得到真确分类的

# %%
# %run classifier.py TRAIN  X:\share\image\mydataset\mtcnnalign_160  X:/share/model/20180402-114759/20180402-114759.pb  X:\share\model\classifiter\aberdeen.pkl
# Out:
# D:\myGit\github\facenet\src\classifier.py:60: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(len(cls.image_paths)>0, 'There must be at least one image for each class in the dataset')
# Number of classes: 101
# Number of images: 428
# Loading feature extraction model
# Model filename: X:/share/model/20180402-114759/20180402-114759.pb
# Calculating features for images
# Training classifier
# Saved classifier model to file "X:\share\model\classifiter\aberdeen.pkl"

# %%
# %run classifier.py CLASSIFY  X:/share/image/mydataset/test_img/  X:/share/model/20180402-114759/20180402-114759.pb  X:\share\model\classifiter\aberdeen.pkl
# Out:
# D:\myGit\github\facenet\src\classifier.py:60: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(len(cls.image_paths)>0, 'There must be at least one image for each class in the dataset')
# Number of classes: 32
# Number of images: 251
# Loading feature extraction model
# Model filename: X:/share/model/20180402-114759/20180402-114759.pb
# Calculating features for images
# Testing classifier
# Loaded classifier model from file "X:\share\model\classifiter\aberdeen.pkl"
#    0  mmanson: 0.057
#    1  mmanson: 0.047
#    2  mmanson: 0.048
#    3  mmanson: 0.059
#    4  mmanson: 0.062
#    5  mmanson: 0.057
#    6  mmanson: 0.059
#    7  mmanson: 0.046
#    8  mmanson: 0.046
#    9  andrew: 0.058
#   10  mmanson: 0.036
#   11  bfegan: 0.030
#   12  dave faquhar: 0.035
#   13  andrew: 0.039
#   14  andrew: 0.041
#   15  andrew: 0.036
#   16  andrew: 0.034
#   17  caroline: 0.035
#   18  dave faquhar: 0.036
#   19  mmanson: 0.037
#   20  alister: 0.032
# ...
