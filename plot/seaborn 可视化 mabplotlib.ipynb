# %% [markdown]
# # https://www.jianshu.com/p/3bb2cc453df1
# # seaborn  美化matpoltlib
# # API http://seaborn.pydata.org/api.html

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline 
sns.set(style="white", color_codes=True)
from sklearn.datasets import load_iris 
iris_data = load_iris() 
iris = pd.DataFrame(iris_data['data'], columns=iris_data['feature_names']) 
iris = pd.merge(iris, pd.DataFrame(iris_data['target'], columns=['species']), left_index=True, right_index=True) 
labels = dict(zip([0,1,2], iris_data['target_names'])) 
iris['species'] = iris['species'].apply(lambda x: labels[x]) 
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
sns.lmplot(x="sepal length (cm)",y="sepal width (cm)",data=iris)
# Out:
# c:\program files\python36\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.FacetGrid(iris, hue='species',size=6) \
   .map(sns.kdeplot, 'petal length (cm)') \
    .add_legend()
# Out:
# c:\program files\python36\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
from sklearn.manifold import TSNE

iris_embedded = TSNE(n_components=2).fit_transform(iris.iloc[:,:-1])

pos = pd.DataFrame(iris_embedded, columns=['X','Y'])
pos['species'] = iris['species']
ax = pos[pos['species']=='virginica'].plot(kind='scatter', x='X', y='Y', color='blue', label='virgnica')
pos[pos['species']=='setosa'].plot(kind='scatter', x='X', y='Y', color='green', label='setosa', ax=ax) 
pos[pos['species']=='versicolor'].plot(kind='scatter', x='X', y='Y', color='red', label='versicolor', ax=ax)

# %% [markdown]
# # 散点图

# %%
from sklearn.datasets.samples_generator import make_blobs


# #############################################################################
# Generate sample data
centers = [[1, 1], [-1, -1], [1, -1]]
X, labels_true = make_blobs(n_samples=750, centers=centers, cluster_std=0.4,
                            random_state=0)
X=pd.DataFrame(X,columns=["x","y"])
sns.lmplot(x="x",y="y",data=X)
# Out:
# c:\program files\python36\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.FacetGrid(X, hue='species',size=6) \
   .map(sns.kdeplot, 'x') \
    .add_legend()
# Out:
# c:\program files\python36\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-ba20883c2f3a> in <module>()
# ----> 1 sns.FacetGrid(X, hue='x',size=6)    .map(sns.kdeplot, 'x')     .add_legend()
#
# c:\program files\python36\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     752
#     753             # Draw the plot
# --> 754             self._facet_plot(func, ax, plot_args, kwargs)
#     755
#     756         # Finalize the annotations and layout
#
# c:\program files\python36\lib\site-packages\seaborn\axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     836
#     837         # Draw the plot
# --> 838         func(*plot_args, **plot_kwargs)
#     839
#     840         # Sort out the supporting information
#
# c:\program files\python36\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     689         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     690                                  gridsize, cut, clip, legend, ax,
# --> 691                                  cumulative=cumulative, **kwargs)
#     692
#     693     return ax
#
# c:\program files\python36\lib\site-packages\seaborn\distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     292                               "only implemented in statsmodels."
#     293                               "Please install statsmodels.")
# --> 294         x, y = _scipy_univariate_kde(data, bw, gridsize, cut, clip)
#     295
#     296     # Make sure the density is nonnegative
#
# c:\program files\python36\lib\site-packages\seaborn\distributions.py in _scipy_univariate_kde(data, bw, gridsize, cut, clip)
#     364     """Compute a univariate kernel density estimate using scipy."""
#     365     try:
# --> 366         kde = stats.gaussian_kde(data, bw_method=bw)
#     367     except TypeError:
#     368         kde = stats.gaussian_kde(data)
#
# c:\program files\python36\lib\site-packages\scipy\stats\kde.py in __init__(self, dataset, bw_method)
#     167         self.dataset = atleast_2d(dataset)
#     168         if not self.dataset.size > 1:
# --> 169             raise ValueError("`dataset` input should have multiple elements.")
#     170
#     171         self.d, self.n = self.dataset.shape
#
# ValueError: `dataset` input should have multiple elements.

# %% [markdown]
# # mabplotlib

# %% [markdown]
# # 显示图片

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline 
from PIL import Image             ##调用库
import matplotlib.image as mpimg # mpimg 用于读取图片

# %%
#y显示原图
image1=r"D:/docker/mnt/openface/data/mydataset/test_img/tock16.jpg"
im = mpimg.imread(image1)  ##文件存在的路径
plt.imshow(im)

# %% [markdown]
# # 封闭框

# %%
import matplotlib.patches as patches
plt.figure(8)
plt.imshow(im)
currentAxis=plt.gca()
rect=patches.Rectangle((100, 100),100,100,linewidth=1,edgecolor='r',facecolor='none')
currentAxis.add_patch(rect)
