# %%
import glob

# %%
print( glob.glob(r"C:\Users\user\Pictures\Aberdeen\*.jpg"))
# Out:
# ['C:\\Users\\user\\Pictures\\Aberdeen\\adrian1.jpg', 'C:\\Users\\user\\Pictures\\Aberdeen\\adrian2.jpg', 'C:\\Users\\user\\Pictures\\Aberdeen\\adrian3.jpg', 'C:\\Users\\user\\Pictures\\Aberdeen\\adrian4.jpg', 'C:\\Users\\user\\Pictures\\Aberdeen\\alec1.jpg', 'C:\\Users\\user\\Pictures\\Aberdeen\\alison1.jpg', 'C:\\Users\\user\\Pictures\\Aberdeen\\alison2.jpg', 'C:\\Users\\user\\Pictures\\Aberdeen\\alison3.jpg', 'C:\\Users\\user\\Pictures\\Aberdeen\\alison4.jpg', 'C:\\Users\\user\\Pictures\\Aberdeen\\alister1.jpg', 'C:\\Users\\user\\Pictures\\Aberdeen\\alister2.jpg', 'C:\\Users\\user\\Pictures\\Aberdeen\\alister3.jpg', 'C:\\Users\\user\\Pictures\\Aberdeen\\alister4.jpg', 'C:\\Users\\user\\Pictures\\Aberdeen\\amellanby1.jpg', 'C:\\Users\\user\\Pictures\\Aberdeen\\amellanby10.jpg', 'C:\\Users\\user\\Pictures\\Aberdeen\\amellanby11.jpg', 'C:\\Users\\user\\Pictures\\Aberdeen\\amellanby12.jpg', 'C:\\Users\\user\\Pictures\\Aberdeen\\amellanby13.jpg', 'C:\\Users\\user\\Pictures\\Aberdeen\\am
# ...

# %% [markdown]
# # 单词

# %% [markdown]
# ## 英文

# %% [markdown]
# ### 书写聚类

# %% [markdown]
# ### 词义聚类，词性等多维聚类

# %% [markdown]
# ## 中文

# %% [markdown]
# # 句子
